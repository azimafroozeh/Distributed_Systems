# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("record.xlsx")

# %%
plt.rcParams['figure.dpi'] = 300

# %%
plt.plot(df.T)
plt.xticks(df.columns)
legend=plt.legend(df.index)

#plt.title("Performance on map phase")
plt.ylabel('Time(s)')
plt.xlabel('Number of Node')
plt.grid()
plt.savefig('running_time.png',transparent=True)
plt.show()

# plt.savefig('test.png',transparent=True)

# %%
df.index
# Out:
# Index(['Small', 'Middle', 'Large', 'Huge'], dtype='object')

# %%
df
# Out:
#                  1          2          3          4
# Small    16.867314  12.447662  12.696982  12.837300
# Middle   21.543825  13.247132  13.093345  13.101878
# Large    83.683331  47.505300  35.475263  29.570622
# Huge    174.085651  98.774086  81.050092  63.924501

# %%
speedup_df=df.div(df[1],axis='index')

# %%
speedup_df=1/speedup_df

# %%
plt.plot(speedup_df.T)
plt.xticks(speedup_df.columns)
plt.legend(df.index)
#plt.title("Performance on map phase")
plt.grid()
plt.xlabel('Number of Node')

plt.ylabel('Speed Up')
plt.savefig('speedup.png',transparent=True)
plt.show()
